# %% [markdown]
# # Basic Model

# %% [markdown]
# ## 🌐 Connect Colab to Google Drive

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/[2024-2025] AN2DL/
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/[2024-2025] AN2DL

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# %%
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


np.random.seed(42)
tf.random.set_seed(42);

import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

import matplotlib.gridspec as gridspec

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('training_set.npz')
X = data['images']
y = data['labels']

# %%
class_name = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet",
}

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# %%
# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (11144, 96, 96, 3)
# Training Label Shape: (11144, 8)
# Validation Data Shape: (1239, 96, 96, 3)
# Validation Label Shape: (1239, 8)

# %%
# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Categorical label: [1. 0. 0. 0. 0. 0. 0. 0.]
# "Default" label: 0
# Classification:  Basophil

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='01-ConvolutionsFlattenDense')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv1 (Conv2D)                      │ (None, 96, 96, 32)           │           896 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act1 (Activation)                   │ (None, 96, 96, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp1 (MaxPooling2D)                  │ (None, 48, 48, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2 (Conv2D)                      │ (None, 48, 48, 64)           │        18,496 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act2 (Activation)                   │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp2 (MaxPooling2D)                  │ (None, 24, 24, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ flatten (Flatten)                   │ (None, 36864)                │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 8)                    │       294,920 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ softmax (Activation)                │ (None, 8)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 314,312 (1.20 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.4090 - loss: 1.6363 - val_accuracy: 0.6949 - val_loss: 0.8968
# Epoch 2/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7356 - loss: 0.7648 - val_accuracy: 0.7853 - val_loss: 0.6007
# Epoch 3/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7967 - loss: 0.5830 - val_accuracy: 0.7893 - val_loss: 0.5671
# Epoch 4/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8106 - loss: 0.5297 - val_accuracy: 0.8160 - val_loss: 0.5075
# Epoch 5/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8281 - loss: 0.4875 - val_accuracy: 0.8216 - val_loss: 0.4779
# Epoch 6/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8363 - loss: 0.4515 - val_accuracy: 0.8329 - val_loss: 0.4556
# Epoch 7/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8487 - loss: 0.4196 - val_accuracy: 0.8354 - val_loss: 0.4640
# Epoch 8/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8559 - loss: 0.3968 - val_accuracy: 0.8273 - val_loss: 0.4709
# Epoch 9/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8587 - loss: 0.3785 - val_accuracy: 0.8289 - val_loss: 0.4663
# Epoch 10/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8651 - loss: 0.3594 - val_accuracy: 0.8313 - val_loss: 0.4557
# Epoch 11/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8740 - loss: 0.3432 - val_accuracy: 0.8329 - val_loss: 0.4732
# Epoch 12/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8772 - loss: 0.3380 - val_accuracy: 0.8394 - val_loss: 0.4529
# Epoch 13/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8790 - loss: 0.3261 - val_accuracy: 0.8370 - val_loss: 0.4497
# Epoch 14/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8836 - loss: 0.3081 - val_accuracy: 0.8305 - val_loss: 0.4531
# Epoch 15/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8866 - loss: 0.2974 - val_accuracy: 0.8305 - val_loss: 0.4715
# Epoch 16/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8894 - loss: 0.2934 - val_accuracy: 0.8313 - val_loss: 0.4559
# Epoch 17/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8925 - loss: 0.2916 - val_accuracy: 0.8410 - val_loss: 0.4513
# Epoch 18/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8916 - loss: 0.2851 - val_accuracy: 0.8208 - val_loss: 0.5061
# Epoch 19/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8918 - loss: 0.2869 - val_accuracy: 0.8249 - val_loss: 0.5248
# Epoch 20/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8925 - loss: 0.2793 - val_accuracy: 0.8224 - val_loss: 0.5179
# Epoch 21/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8924 - loss: 0.2791 - val_accuracy: 0.8362 - val_loss: 0.4842
# Epoch 22/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8933 - loss: 0.2738 - val_accuracy: 0.8257 - val_loss: 0.5128
# Epoch 23/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8939 - loss: 0.2751 - val_accuracy: 0.8249 - val_loss: 0.5213
# Epoch 24/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8911 - loss: 0.2785 - val_accuracy: 0.8249 - val_loss: 0.5286
# Epoch 25/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8934 - loss: 0.2753 - val_accuracy: 0.8345 - val_loss: 0.5165
# Epoch 26/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8916 - loss: 0.2748 - val_accuracy: 0.8200 - val_loss: 0.5609
# Epoch 27/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8923 - loss: 0.2702 - val_accuracy: 0.8402 - val_loss: 0.5513
# Epoch 28/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8915 - loss: 0.2743 - val_accuracy: 0.8273 - val_loss: 0.6002
# Epoch 29/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8931 - loss: 0.2702 - val_accuracy: 0.8216 - val_loss: 0.5784
# Epoch 30/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8897 - loss: 0.2757 - val_accuracy: 0.8370 - val_loss: 0.5385
# Epoch 31/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8889 - loss: 0.2760 - val_accuracy: 0.8362 - val_loss: 0.5475
# Epoch 32/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8936 - loss: 0.2624 - val_accuracy: 0.8394 - val_loss: 0.5846
# Epoch 33/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8975 - loss: 0.2569 - val_accuracy: 0.8297 - val_loss: 0.6354
# Epoch 34/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8950 - loss: 0.2582 - val_accuracy: 0.8386 - val_loss: 0.5911
# Epoch 35/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8965 - loss: 0.2542 - val_accuracy: 0.8394 - val_loss: 0.5571
# Epoch 36/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8964 - loss: 0.2526 - val_accuracy: 0.8329 - val_loss: 0.5904
# Epoch 37/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8957 - loss: 0.2524 - val_accuracy: 0.8329 - val_loss: 0.5933
# Final validation accuracy: 84.1%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_84.58.keras')

# %%
def extract_activations(model, X, num_images):

    # Identify the first convolutional layer
    first_conv_index = None
    for i, layer in enumerate(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            first_conv_index = i
            break

    if first_conv_index is None:
        raise ValueError("The model does not contain a 2D convolution")

    # Extract activations from the first convolutional layer
    first_conv = tfk.Sequential(model.layers[:first_conv_index + 1])
    first_activations = first_conv(X[:num_images])

    # Identify the first pooling layer after the first convolution
    pooling_index = None
    for i, layer in enumerate(model.layers[first_conv_index + 1:], start=first_conv_index + 1):
        if isinstance(layer, (tfk.layers.MaxPooling2D, tfk.layers.AveragePooling2D)):
            pooling_index = i
            break

    if pooling_index is None:
        raise ValueError("The model does not contain a 2D pooling operation after the first convolution")

    # Extract activations from the first convolution and the first pooling layer
    second_conv = tfk.Sequential(model.layers[:pooling_index + 1])
    second_activations = second_conv(X[:num_images])

    return first_activations, second_activations

def find_last_conv_layer(model):

    # Identify the last convolutional layer in the model
    for layer in reversed(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            return layer.name
    raise ValueError("No Conv2D layer found in the model.")

def visualize(model, X, y, unique_labels, num_images=50, display_activations=True):

    # Extract activations from the model
    first_activations, second_activations = extract_activations(model, X, num_images)

    # Select a random image for prediction and visualisation
    image = np.random.randint(0, num_images)
    predictions = model.predict(np.expand_dims(X[image], axis=0), verbose=0)
    class_int = np.argmax(predictions[0])
    class_str = unique_labels[class_int]

    # Create figure layout for displaying the image and predictions
    fig = plt.figure(constrained_layout=True, figsize=(16, 4))
    gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[1.5, 1.5], wspace=0)

    # Display the selected image with the true class
    ax1 = fig.add_subplot(gs[0])
    ax1.set_title(f"True class: {unique_labels[np.argmax(y[image])]}", loc='left')
    if X[image].shape[-1] == 1:
        ax1.imshow(np.squeeze(X[image]), cmap='bone', vmin=0., vmax=1.)
    else:
        ax1.imshow(np.squeeze(X[image]), vmin=0., vmax=1.)
    ax1.axis('off')

    # Display the prediction bar
    ax2 = fig.add_subplot(gs[1])
    ax2.barh(list(class_name.keys()), np.squeeze(predictions, axis=0), color=plt.get_cmap('tab10').colors)
    ax2.set_title(f"Predicted class: {class_str} (Confidence: {max(np.squeeze(predictions, axis=0)):.2f})", loc='left')
    ax2.grid(alpha=0.3)
    ax2.set_xlim(0.0, 1.0)

    plt.show()

    # Display activations if required
    if display_activations:
        # Visualise the activations from the first convolutional layer
        fig, axes = plt.subplots(1, 8, figsize=(16, 14))
        for i in range(8):
            ax = axes[i]
            ax.imshow(first_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('First convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

        # Visualise the activations from the first pooling layer
        fig, axes = plt.subplots(2, 8, figsize=(16, 5))
        for i in range(16):
            ax = axes[i // 8, i % 8]
            ax.imshow(second_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('Second convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (1376, 8)

# %%
# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.8438
# Precision score over the test set: 0.8932
# Recall score over the test set: 0.8438
# F1 score over the test set: 0.8564

# %% [markdown]
# <hr>

# %% [markdown]
# # Basic Model with data balanced by Up Sampling

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('increased_balanced_dataset_noBrightness_noContrast_noZoom.npz')
X = data['images']
y = data['labels']

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# %%
# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (15277, 96, 96, 3)
# Training Label Shape: (15277, 8)
# Validation Data Shape: (1698, 96, 96, 3)
# Validation Label Shape: (1698, 8)

# %%
# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Categorical label: [1. 0. 0. 0. 0. 0. 0. 0.]
# "Default" label: 0
# Classification:  Basophil

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='01-ConvolutionsFlattenDense')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "01-ConvolutionsFlattenDense"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv1 (Conv2D)                      │ (None, 96, 96, 32)           │           896 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act1 (Activation)                   │ (None, 96, 96, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp1 (MaxPooling2D)                  │ (None, 48, 48, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2 (Conv2D)                      │ (None, 48, 48, 64)           │        18,496 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act2 (Activation)                   │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp2 (MaxPooling2D)                  │ (None, 24, 24, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ flatten (Flatten)                   │ (None, 36864)                │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 8)                    │       294,920 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ softmax (Activation)                │ (None, 8)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 314,312 (1.20 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.4231 - loss: 1.5680 - val_accuracy: 0.7527 - val_loss: 0.7009
# Epoch 2/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7477 - loss: 0.7001 - val_accuracy: 0.7768 - val_loss: 0.6338
# Epoch 3/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7953 - loss: 0.5738 - val_accuracy: 0.7880 - val_loss: 0.5810
# Epoch 4/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8215 - loss: 0.4911 - val_accuracy: 0.7845 - val_loss: 0.5937
# Epoch 5/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8387 - loss: 0.4472 - val_accuracy: 0.7727 - val_loss: 0.6226
# Epoch 6/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8442 - loss: 0.4256 - val_accuracy: 0.7786 - val_loss: 0.6318
# Epoch 7/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8514 - loss: 0.4024 - val_accuracy: 0.7886 - val_loss: 0.6226
# Epoch 8/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8599 - loss: 0.3789 - val_accuracy: 0.8092 - val_loss: 0.5426
# Epoch 9/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.8636 - loss: 0.3624 - val_accuracy: 0.8316 - val_loss: 0.4614
# Epoch 10/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8740 - loss: 0.3333 - val_accuracy: 0.8351 - val_loss: 0.4571
# Epoch 11/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8832 - loss: 0.3130 - val_accuracy: 0.8304 - val_loss: 0.5016
# Epoch 12/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8815 - loss: 0.3101 - val_accuracy: 0.8310 - val_loss: 0.5301
# Epoch 13/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8944 - loss: 0.2864 - val_accuracy: 0.8245 - val_loss: 0.5089
# Epoch 14/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8952 - loss: 0.2823 - val_accuracy: 0.8363 - val_loss: 0.5082
# Epoch 15/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.8982 - loss: 0.2732 - val_accuracy: 0.8333 - val_loss: 0.4981
# Epoch 16/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9006 - loss: 0.2628 - val_accuracy: 0.8398 - val_loss: 0.4729
# Epoch 17/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9062 - loss: 0.2453 - val_accuracy: 0.8369 - val_loss: 0.5027
# Epoch 18/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9082 - loss: 0.2413 - val_accuracy: 0.8375 - val_loss: 0.4760
# Epoch 19/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9117 - loss: 0.2366 - val_accuracy: 0.8286 - val_loss: 0.5066
# Epoch 20/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9139 - loss: 0.2249 - val_accuracy: 0.8380 - val_loss: 0.4726
# Epoch 21/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9156 - loss: 0.2202 - val_accuracy: 0.8345 - val_loss: 0.5394
# Epoch 22/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9189 - loss: 0.2146 - val_accuracy: 0.8274 - val_loss: 0.5747
# Epoch 23/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9193 - loss: 0.2133 - val_accuracy: 0.8386 - val_loss: 0.5210
# Epoch 24/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9191 - loss: 0.2126 - val_accuracy: 0.8416 - val_loss: 0.5241
# Epoch 25/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9195 - loss: 0.2094 - val_accuracy: 0.8316 - val_loss: 0.5284
# Epoch 26/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9221 - loss: 0.2043 - val_accuracy: 0.8115 - val_loss: 0.6341
# Epoch 27/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9217 - loss: 0.2031 - val_accuracy: 0.8210 - val_loss: 0.6259
# Epoch 28/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9205 - loss: 0.2048 - val_accuracy: 0.8204 - val_loss: 0.6497
# Epoch 29/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9183 - loss: 0.2078 - val_accuracy: 0.8245 - val_loss: 0.6211
# Epoch 30/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9176 - loss: 0.2117 - val_accuracy: 0.8486 - val_loss: 0.5652
# Epoch 31/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9198 - loss: 0.2016 - val_accuracy: 0.8145 - val_loss: 0.7001
# Epoch 32/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9210 - loss: 0.2022 - val_accuracy: 0.8239 - val_loss: 0.6776
# Epoch 33/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9154 - loss: 0.2131 - val_accuracy: 0.8504 - val_loss: 0.5527
# Epoch 34/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9208 - loss: 0.2041 - val_accuracy: 0.8445 - val_loss: 0.5821
# Epoch 35/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9213 - loss: 0.1970 - val_accuracy: 0.8110 - val_loss: 0.7652
# Epoch 36/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9195 - loss: 0.2053 - val_accuracy: 0.8316 - val_loss: 0.6400
# Epoch 37/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9161 - loss: 0.2126 - val_accuracy: 0.8445 - val_loss: 0.6070
# Epoch 38/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9215 - loss: 0.1940 - val_accuracy: 0.8404 - val_loss: 0.5897
# Epoch 39/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9216 - loss: 0.1984 - val_accuracy: 0.8486 - val_loss: 0.5855
# Epoch 40/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9205 - loss: 0.1952 - val_accuracy: 0.8386 - val_loss: 0.6688
# Epoch 41/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9230 - loss: 0.1920 - val_accuracy: 0.8522 - val_loss: 0.5749
# Epoch 42/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9229 - loss: 0.1912 - val_accuracy: 0.8292 - val_loss: 0.6025
# Epoch 43/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9167 - loss: 0.2061 - val_accuracy: 0.8392 - val_loss: 0.7055
# Epoch 44/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9120 - loss: 0.2183 - val_accuracy: 0.8545 - val_loss: 0.6118
# Epoch 45/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9219 - loss: 0.1965 - val_accuracy: 0.8516 - val_loss: 0.5856
# Epoch 46/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9220 - loss: 0.1899 - val_accuracy: 0.8398 - val_loss: 0.6142
# Epoch 47/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9233 - loss: 0.1891 - val_accuracy: 0.8510 - val_loss: 0.5793
# Epoch 48/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9222 - loss: 0.1883 - val_accuracy: 0.8516 - val_loss: 0.5943
# Epoch 49/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9227 - loss: 0.1876 - val_accuracy: 0.8486 - val_loss: 0.6146
# Epoch 50/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9217 - loss: 0.1898 - val_accuracy: 0.8180 - val_loss: 0.8183
# Epoch 51/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9157 - loss: 0.2112 - val_accuracy: 0.8322 - val_loss: 0.7130
# Epoch 52/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9146 - loss: 0.2205 - val_accuracy: 0.8504 - val_loss: 0.6824
# Epoch 53/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9198 - loss: 0.1997 - val_accuracy: 0.8433 - val_loss: 0.6978
# Epoch 54/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9224 - loss: 0.1883 - val_accuracy: 0.8486 - val_loss: 0.6757
# Epoch 55/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9238 - loss: 0.1886 - val_accuracy: 0.8592 - val_loss: 0.5881
# Epoch 56/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9226 - loss: 0.1882 - val_accuracy: 0.8492 - val_loss: 0.7050
# Epoch 57/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9164 - loss: 0.2045 - val_accuracy: 0.8080 - val_loss: 0.9321
# Epoch 58/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9222 - loss: 0.1964 - val_accuracy: 0.8345 - val_loss: 0.7446
# Epoch 59/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9229 - loss: 0.1915 - val_accuracy: 0.8598 - val_loss: 0.6027
# Epoch 60/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9215 - loss: 0.1874 - val_accuracy: 0.8551 - val_loss: 0.5955
# Epoch 61/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9226 - loss: 0.1860 - val_accuracy: 0.8528 - val_loss: 0.6115
# Epoch 62/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9222 - loss: 0.1858 - val_accuracy: 0.8539 - val_loss: 0.6219
# Epoch 63/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9235 - loss: 0.1861 - val_accuracy: 0.8587 - val_loss: 0.6194
# Epoch 64/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9221 - loss: 0.1854 - val_accuracy: 0.8539 - val_loss: 0.6281
# Epoch 65/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9228 - loss: 0.1855 - val_accuracy: 0.8587 - val_loss: 0.5971
# Epoch 66/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9236 - loss: 0.1853 - val_accuracy: 0.8587 - val_loss: 0.6109
# Epoch 67/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9227 - loss: 0.1854 - val_accuracy: 0.8534 - val_loss: 0.7001
# Epoch 68/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9048 - loss: 0.2450 - val_accuracy: 0.8398 - val_loss: 0.6505
# Epoch 69/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9218 - loss: 0.1911 - val_accuracy: 0.8534 - val_loss: 0.5861
# Epoch 70/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9225 - loss: 0.1854 - val_accuracy: 0.8534 - val_loss: 0.5799
# Epoch 71/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9231 - loss: 0.1848 - val_accuracy: 0.8563 - val_loss: 0.5858
# Epoch 72/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9232 - loss: 0.1848 - val_accuracy: 0.8598 - val_loss: 0.5614
# Epoch 73/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9234 - loss: 0.1846 - val_accuracy: 0.8598 - val_loss: 0.5448
# Epoch 74/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9232 - loss: 0.1847 - val_accuracy: 0.8557 - val_loss: 0.5907
# Epoch 75/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9224 - loss: 0.1846 - val_accuracy: 0.8581 - val_loss: 0.5889
# Epoch 76/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9226 - loss: 0.1846 - val_accuracy: 0.8539 - val_loss: 0.6318
# Epoch 77/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9217 - loss: 0.1854 - val_accuracy: 0.8598 - val_loss: 0.5941
# Epoch 78/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9224 - loss: 0.1849 - val_accuracy: 0.8481 - val_loss: 0.6542
# Epoch 79/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9232 - loss: 0.1845 - val_accuracy: 0.8545 - val_loss: 0.5768
# Final validation accuracy: 85.98%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_85.98.keras')

# %%
# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (1887, 8)

# %%
# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.84
# Precision score over the test set: 0.8679
# Recall score over the test set: 0.84
# F1 score over the test set: 0.8448

# %% [markdown]
# # Basic Model with data balanced by Down Sampling

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('reduced_balanced_dataset.npz')
X = data['images']
y = data['lables']

# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)

# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Training Data Shape: (6908, 96, 96, 3)
# Training Label Shape: (6908, 8)
# Validation Data Shape: (768, 96, 96, 3)
# Validation Label Shape: (768, 8)
# Categorical label: [0. 0. 0. 0. 1. 0. 0. 0.]
# "Default" label: 4
# Classification:  Lymphocyte

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='01-ConvolutionsFlattenDense')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 0.2859 - loss: 1.8852 - val_accuracy: 0.5404 - val_loss: 1.3000
# Epoch 2/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.5256 - loss: 1.2743 - val_accuracy: 0.6198 - val_loss: 1.0697
# Epoch 3/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6024 - loss: 1.0687 - val_accuracy: 0.6458 - val_loss: 0.9777
# Epoch 4/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6481 - loss: 0.9383 - val_accuracy: 0.6810 - val_loss: 0.8912
# Epoch 5/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6865 - loss: 0.8537 - val_accuracy: 0.7070 - val_loss: 0.8288
# Epoch 6/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7107 - loss: 0.7835 - val_accuracy: 0.7435 - val_loss: 0.7620
# Epoch 7/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7262 - loss: 0.7284 - val_accuracy: 0.7344 - val_loss: 0.7192
# Epoch 8/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7356 - loss: 0.6958 - val_accuracy: 0.7461 - val_loss: 0.7038
# Epoch 9/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7591 - loss: 0.6446 - val_accuracy: 0.7578 - val_loss: 0.6885
# Epoch 10/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7685 - loss: 0.6088 - val_accuracy: 0.7461 - val_loss: 0.6967
# Epoch 11/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7813 - loss: 0.5813 - val_accuracy: 0.7448 - val_loss: 0.7109
# Epoch 12/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7916 - loss: 0.5580 - val_accuracy: 0.7253 - val_loss: 0.7529
# Epoch 13/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7936 - loss: 0.5390 - val_accuracy: 0.7344 - val_loss: 0.7297
# Epoch 14/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7980 - loss: 0.5328 - val_accuracy: 0.7292 - val_loss: 0.7760
# Epoch 15/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8028 - loss: 0.5121 - val_accuracy: 0.7227 - val_loss: 0.8186
# Epoch 16/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8067 - loss: 0.5096 - val_accuracy: 0.7461 - val_loss: 0.7329
# Epoch 17/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8173 - loss: 0.4976 - val_accuracy: 0.7292 - val_loss: 0.7797
# Epoch 18/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8083 - loss: 0.5020 - val_accuracy: 0.7227 - val_loss: 0.7804
# Epoch 19/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8135 - loss: 0.4865 - val_accuracy: 0.7435 - val_loss: 0.7400
# Epoch 20/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8185 - loss: 0.4756 - val_accuracy: 0.7057 - val_loss: 0.9262
# Epoch 21/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8125 - loss: 0.4783 - val_accuracy: 0.7253 - val_loss: 0.8142
# Epoch 22/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8163 - loss: 0.4689 - val_accuracy: 0.7109 - val_loss: 0.9300
# Epoch 23/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8214 - loss: 0.4668 - val_accuracy: 0.7279 - val_loss: 0.8610
# Epoch 24/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8227 - loss: 0.4602 - val_accuracy: 0.7474 - val_loss: 0.7775
# Epoch 25/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8186 - loss: 0.4623 - val_accuracy: 0.7578 - val_loss: 0.7212
# Epoch 26/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8163 - loss: 0.4664 - val_accuracy: 0.7656 - val_loss: 0.6912
# Epoch 27/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8220 - loss: 0.4520 - val_accuracy: 0.7682 - val_loss: 0.6906
# Epoch 28/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8225 - loss: 0.4549 - val_accuracy: 0.7721 - val_loss: 0.7032
# Epoch 29/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8243 - loss: 0.4450 - val_accuracy: 0.7604 - val_loss: 0.7438
# Epoch 30/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.8251 - loss: 0.4417 - val_accuracy: 0.7461 - val_loss: 0.7892
# Epoch 31/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8156 - loss: 0.4564 - val_accuracy: 0.7370 - val_loss: 0.7855
# Epoch 32/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8206 - loss: 0.4434 - val_accuracy: 0.7201 - val_loss: 0.8499
# Epoch 33/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8191 - loss: 0.4379 - val_accuracy: 0.7370 - val_loss: 0.8224
# Epoch 34/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8227 - loss: 0.4335 - val_accuracy: 0.7630 - val_loss: 0.7261
# Epoch 35/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.8239 - loss: 0.4275 - val_accuracy: 0.7604 - val_loss: 0.7393
# Epoch 36/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.8235 - loss: 0.4297 - val_accuracy: 0.7669 - val_loss: 0.7237
# Epoch 37/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8290 - loss: 0.4225 - val_accuracy: 0.7604 - val_loss: 0.7592
# Epoch 38/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8263 - loss: 0.4229 - val_accuracy: 0.7695 - val_loss: 0.7367
# Epoch 39/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8270 - loss: 0.4235 - val_accuracy: 0.7721 - val_loss: 0.7716
# Epoch 40/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8287 - loss: 0.4194 - val_accuracy: 0.7708 - val_loss: 0.7635
# Epoch 41/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8272 - loss: 0.4187 - val_accuracy: 0.7721 - val_loss: 0.8010
# Epoch 42/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8285 - loss: 0.4177 - val_accuracy: 0.7591 - val_loss: 0.7806
# Epoch 43/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8243 - loss: 0.4181 - val_accuracy: 0.7630 - val_loss: 0.8021
# Epoch 44/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8262 - loss: 0.4170 - val_accuracy: 0.7708 - val_loss: 0.7724
# Epoch 45/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8257 - loss: 0.4160 - val_accuracy: 0.7526 - val_loss: 0.7803
# Epoch 46/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8274 - loss: 0.4166 - val_accuracy: 0.7656 - val_loss: 0.7982
# Epoch 47/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8281 - loss: 0.4143 - val_accuracy: 0.7643 - val_loss: 0.7841
# Epoch 48/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8271 - loss: 0.4163 - val_accuracy: 0.7565 - val_loss: 0.8203
# Final validation accuracy: 77.21%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_77.21.keras')

# %%
# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (853, 8)
# Accuracy score over the test set: 0.7773
# Precision score over the test set: 0.8493
# Recall score over the test set: 0.7773
# F1 score over the test set: 0.7916

# %% [markdown]
# <hr>

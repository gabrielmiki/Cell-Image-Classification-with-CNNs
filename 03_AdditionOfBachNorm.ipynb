# %% [markdown]
# # Basic Model plus Augmentation and Batch Normalization

# %% [markdown]
# ## 🌐 Connect Colab to Google Drive

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/[2024-2025] AN2DL/
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/[2024-2025] AN2DL

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# %%
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

np.random.seed(42)
tf.random.set_seed(42);

import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

import matplotlib.gridspec as gridspec

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('training_set.npz')
X = data['images']
y = data['labels']

# %%
class_name = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet",
}

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# %%
# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (11144, 96, 96, 3)
# Training Label Shape: (11144, 8)
# Validation Data Shape: (1239, 96, 96, 3)
# Validation Label Shape: (1239, 8)

# %%
# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Categorical label: [1. 0. 0. 0. 0. 0. 0. 0.]
# "Default" label: 0
# Classification:  Basophil

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

# Define a sequential model for image augmentation with various transformations
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(0.2),
    tfkl.RandomZoom(0.2),
#    tfkl.RandomBrightness(0.5, value_range=(0,1)),
#    tfkl.RandomContrast(0.75),
], name='Augmentation')

x = augmentation(inputs)

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.BatchNormalization(name='bn1')(x)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.BatchNormalization(name='bn2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='03-AdditionOfBachNorm')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv1 (Conv2D)                      │ (None, 96, 96, 32)           │           896 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ bn1 (BatchNormalization)            │ (None, 96, 96, 32)           │           128 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act1 (Activation)                   │ (None, 96, 96, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp1 (MaxPooling2D)                  │ (None, 48, 48, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2 (Conv2D)                      │ (None, 48, 48, 64)           │        18,496 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ bn2 (BatchNormalization)            │ (None, 48, 48, 64)           │           256 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act2 (Activation)                   │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp2 (MaxPooling2D)                  │ (None, 24, 24, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ flatten (Flatten)                   │ (None, 36864)                │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 8)                    │       294,920 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ softmax (Activation)                │ (None, 8)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 314,696 (1.20 MB)
#  Trainable params: 314,504 (1.20 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.5363 - loss: 5.2127 - val_accuracy: 0.2825 - val_loss: 3.9200
# Epoch 2/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.7697 - loss: 0.7239 - val_accuracy: 0.3608 - val_loss: 3.6569
# Epoch 3/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8093 - loss: 0.5782 - val_accuracy: 0.7603 - val_loss: 0.6989
# Epoch 4/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8339 - loss: 0.4871 - val_accuracy: 0.6400 - val_loss: 1.7923
# Epoch 5/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8286 - loss: 0.4930 - val_accuracy: 0.6917 - val_loss: 1.3481
# Epoch 6/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8480 - loss: 0.4180 - val_accuracy: 0.7659 - val_loss: 0.9819
# Epoch 7/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8603 - loss: 0.3670 - val_accuracy: 0.7708 - val_loss: 0.9117
# Epoch 8/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8583 - loss: 0.3880 - val_accuracy: 0.5222 - val_loss: 4.5589
# Epoch 9/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8603 - loss: 0.3725 - val_accuracy: 0.6344 - val_loss: 1.9432
# Epoch 10/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8528 - loss: 0.3951 - val_accuracy: 0.6675 - val_loss: 1.9447
# Epoch 11/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8595 - loss: 0.3898 - val_accuracy: 0.1445 - val_loss: 15.4398
# Epoch 12/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8605 - loss: 0.3785 - val_accuracy: 0.7748 - val_loss: 0.8668
# Epoch 13/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8874 - loss: 0.2747 - val_accuracy: 0.7248 - val_loss: 1.3225
# Epoch 14/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8912 - loss: 0.2676 - val_accuracy: 0.7466 - val_loss: 1.0440
# Epoch 15/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8902 - loss: 0.2622 - val_accuracy: 0.6086 - val_loss: 2.3569
# Epoch 16/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8895 - loss: 0.2645 - val_accuracy: 0.1550 - val_loss: 20.5287
# Epoch 17/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8896 - loss: 0.2682 - val_accuracy: 0.8386 - val_loss: 0.4903
# Epoch 18/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8907 - loss: 0.2628 - val_accuracy: 0.8362 - val_loss: 0.5288
# Epoch 19/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8935 - loss: 0.2557 - val_accuracy: 0.8249 - val_loss: 0.5870
# Epoch 20/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8945 - loss: 0.2535 - val_accuracy: 0.7094 - val_loss: 1.3210
# Epoch 21/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8953 - loss: 0.2531 - val_accuracy: 0.6893 - val_loss: 1.6610
# Epoch 22/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8891 - loss: 0.2761 - val_accuracy: 0.7926 - val_loss: 0.8392
# Epoch 23/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8921 - loss: 0.2525 - val_accuracy: 0.5843 - val_loss: 2.7836
# Epoch 24/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8897 - loss: 0.2727 - val_accuracy: 0.2833 - val_loss: 11.7179
# Epoch 25/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8712 - loss: 0.3376 - val_accuracy: 0.7708 - val_loss: 0.9760
# Epoch 26/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8882 - loss: 0.2749 - val_accuracy: 0.8224 - val_loss: 0.6006
# Epoch 27/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8899 - loss: 0.2708 - val_accuracy: 0.5730 - val_loss: 2.7864
# Epoch 28/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8875 - loss: 0.2683 - val_accuracy: 0.7869 - val_loss: 0.9942
# Epoch 29/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8934 - loss: 0.2540 - val_accuracy: 0.8555 - val_loss: 0.4991
# Epoch 30/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8920 - loss: 0.2572 - val_accuracy: 0.8289 - val_loss: 0.6103
# Epoch 31/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8845 - loss: 0.2828 - val_accuracy: 0.8103 - val_loss: 0.7013
# Epoch 32/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8917 - loss: 0.2761 - val_accuracy: 0.7724 - val_loss: 1.1909
# Epoch 33/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8760 - loss: 0.3627 - val_accuracy: 0.8184 - val_loss: 0.6636
# Epoch 34/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8942 - loss: 0.2498 - val_accuracy: 0.8515 - val_loss: 0.5022
# Epoch 35/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8964 - loss: 0.2486 - val_accuracy: 0.8539 - val_loss: 0.4738
# Epoch 36/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8982 - loss: 0.2435 - val_accuracy: 0.8563 - val_loss: 0.4503
# Epoch 37/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8978 - loss: 0.2431 - val_accuracy: 0.8547 - val_loss: 0.4853
# Epoch 38/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8982 - loss: 0.2429 - val_accuracy: 0.8563 - val_loss: 0.4870
# Epoch 39/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8985 - loss: 0.2428 - val_accuracy: 0.8386 - val_loss: 0.5634
# Epoch 40/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8991 - loss: 0.2428 - val_accuracy: 0.8475 - val_loss: 0.5287
# Epoch 41/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8989 - loss: 0.2428 - val_accuracy: 0.8458 - val_loss: 0.5431
# Epoch 42/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8987 - loss: 0.2426 - val_accuracy: 0.8119 - val_loss: 0.8113
# Epoch 43/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8999 - loss: 0.2427 - val_accuracy: 0.8329 - val_loss: 0.6598
# Epoch 44/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8989 - loss: 0.2427 - val_accuracy: 0.8321 - val_loss: 0.6395
# Epoch 45/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8991 - loss: 0.2426 - val_accuracy: 0.8563 - val_loss: 0.4829
# Epoch 46/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8992 - loss: 0.2426 - val_accuracy: 0.8386 - val_loss: 0.6024
# Epoch 47/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8990 - loss: 0.2426 - val_accuracy: 0.8095 - val_loss: 0.8521
# Epoch 48/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.8990 - loss: 0.2427 - val_accuracy: 0.8467 - val_loss: 0.5257
# Epoch 49/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8979 - loss: 0.2428 - val_accuracy: 0.7982 - val_loss: 0.7932
# Epoch 50/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8983 - loss: 0.2427 - val_accuracy: 0.8523 - val_loss: 0.5036
# Epoch 51/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8992 - loss: 0.2426 - val_accuracy: 0.8499 - val_loss: 0.4853
# Epoch 52/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8991 - loss: 0.2425 - val_accuracy: 0.8636 - val_loss: 0.4267
# Epoch 53/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8987 - loss: 0.2426 - val_accuracy: 0.8644 - val_loss: 0.4346
# Epoch 54/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8992 - loss: 0.2425 - val_accuracy: 0.8588 - val_loss: 0.4964
# Epoch 55/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8977 - loss: 0.2425 - val_accuracy: 0.8620 - val_loss: 0.4486
# Epoch 56/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8977 - loss: 0.2425 - val_accuracy: 0.8547 - val_loss: 0.4954
# Epoch 57/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8980 - loss: 0.2425 - val_accuracy: 0.8652 - val_loss: 0.4375
# Epoch 58/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8979 - loss: 0.2425 - val_accuracy: 0.8531 - val_loss: 0.5062
# Epoch 59/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8982 - loss: 0.2429 - val_accuracy: 0.8402 - val_loss: 0.5720
# Epoch 60/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8979 - loss: 0.2426 - val_accuracy: 0.8450 - val_loss: 0.5893
# Epoch 61/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8990 - loss: 0.2426 - val_accuracy: 0.8515 - val_loss: 0.5419
# Epoch 62/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8837 - loss: 0.3171 - val_accuracy: 0.2357 - val_loss: 38.3689
# Epoch 63/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8744 - loss: 0.3239 - val_accuracy: 0.7401 - val_loss: 1.3388
# Epoch 64/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8898 - loss: 0.2639 - val_accuracy: 0.8499 - val_loss: 0.4535
# Epoch 65/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8966 - loss: 0.2463 - val_accuracy: 0.8604 - val_loss: 0.4469
# Epoch 66/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8981 - loss: 0.2433 - val_accuracy: 0.8628 - val_loss: 0.4342
# Epoch 67/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8978 - loss: 0.2430 - val_accuracy: 0.8596 - val_loss: 0.4385
# Epoch 68/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8980 - loss: 0.2428 - val_accuracy: 0.8644 - val_loss: 0.4325
# Epoch 69/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8986 - loss: 0.2427 - val_accuracy: 0.8612 - val_loss: 0.4308
# Epoch 70/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8978 - loss: 0.2426 - val_accuracy: 0.8596 - val_loss: 0.4464
# Epoch 71/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8977 - loss: 0.2426 - val_accuracy: 0.8588 - val_loss: 0.4493
# Epoch 72/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8975 - loss: 0.2426 - val_accuracy: 0.8612 - val_loss: 0.4446
# Epoch 73/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8977 - loss: 0.2425 - val_accuracy: 0.8588 - val_loss: 0.4609
# Epoch 74/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8975 - loss: 0.2425 - val_accuracy: 0.8636 - val_loss: 0.4293
# Epoch 75/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8978 - loss: 0.2437 - val_accuracy: 0.8676 - val_loss: 0.4252
# Epoch 76/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8983 - loss: 0.2427 - val_accuracy: 0.8652 - val_loss: 0.4180
# Epoch 77/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8963 - loss: 0.2426 - val_accuracy: 0.8644 - val_loss: 0.4355
# Epoch 78/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8976 - loss: 0.2425 - val_accuracy: 0.8652 - val_loss: 0.4440
# Epoch 79/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8975 - loss: 0.2425 - val_accuracy: 0.8668 - val_loss: 0.4369
# Epoch 80/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8976 - loss: 0.2425 - val_accuracy: 0.8362 - val_loss: 0.6522
# Epoch 81/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8966 - loss: 0.2425 - val_accuracy: 0.8636 - val_loss: 0.4089
# Epoch 82/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8929 - loss: 0.2681 - val_accuracy: 0.1332 - val_loss: 16.1132
# Epoch 83/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8852 - loss: 0.2865 - val_accuracy: 0.8475 - val_loss: 0.4394
# Epoch 84/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8962 - loss: 0.2488 - val_accuracy: 0.8563 - val_loss: 0.4288
# Epoch 85/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8975 - loss: 0.2451 - val_accuracy: 0.8620 - val_loss: 0.4091
# Epoch 86/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8977 - loss: 0.2435 - val_accuracy: 0.8507 - val_loss: 0.4575
# Epoch 87/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8975 - loss: 0.2429 - val_accuracy: 0.8555 - val_loss: 0.4505
# Epoch 88/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8976 - loss: 0.2428 - val_accuracy: 0.8539 - val_loss: 0.4532
# Epoch 89/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8976 - loss: 0.2427 - val_accuracy: 0.8620 - val_loss: 0.4455
# Epoch 90/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8983 - loss: 0.2427 - val_accuracy: 0.8563 - val_loss: 0.4661
# Epoch 91/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8977 - loss: 0.2427 - val_accuracy: 0.8628 - val_loss: 0.4248
# Epoch 92/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8963 - loss: 0.2430 - val_accuracy: 0.8539 - val_loss: 0.4825
# Epoch 93/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8973 - loss: 0.2427 - val_accuracy: 0.8563 - val_loss: 0.5028
# Epoch 94/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8981 - loss: 0.2426 - val_accuracy: 0.8636 - val_loss: 0.4561
# Epoch 95/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8982 - loss: 0.2426 - val_accuracy: 0.8579 - val_loss: 0.4768
# Final validation accuracy: 86.76%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_86.76.keras')

# %%
def extract_activations(model, X, num_images):

    # Identify the first convolutional layer
    first_conv_index = None
    for i, layer in enumerate(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            first_conv_index = i
            break

    if first_conv_index is None:
        raise ValueError("The model does not contain a 2D convolution")

    # Extract activations from the first convolutional layer
    first_conv = tfk.Sequential(model.layers[:first_conv_index + 1])
    first_activations = first_conv(X[:num_images])

    # Identify the first pooling layer after the first convolution
    pooling_index = None
    for i, layer in enumerate(model.layers[first_conv_index + 1:], start=first_conv_index + 1):
        if isinstance(layer, (tfk.layers.MaxPooling2D, tfk.layers.AveragePooling2D)):
            pooling_index = i
            break

    if pooling_index is None:
        raise ValueError("The model does not contain a 2D pooling operation after the first convolution")

    # Extract activations from the first convolution and the first pooling layer
    second_conv = tfk.Sequential(model.layers[:pooling_index + 1])
    second_activations = second_conv(X[:num_images])

    return first_activations, second_activations

def find_last_conv_layer(model):

    # Identify the last convolutional layer in the model
    for layer in reversed(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            return layer.name
    raise ValueError("No Conv2D layer found in the model.")

def visualize(model, X, y, unique_labels, num_images=50, display_activations=True):

    # Extract activations from the model
    first_activations, second_activations = extract_activations(model, X, num_images)

    # Select a random image for prediction and visualisation
    image = np.random.randint(0, num_images)
    predictions = model.predict(np.expand_dims(X[image], axis=0), verbose=0)
    class_int = np.argmax(predictions[0])
    class_str = unique_labels[class_int]

    # Create figure layout for displaying the image and predictions
    fig = plt.figure(constrained_layout=True, figsize=(16, 4))
    gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[1.5, 1.5], wspace=0)

    # Display the selected image with the true class
    ax1 = fig.add_subplot(gs[0])
    ax1.set_title(f"True class: {unique_labels[np.argmax(y[image])]}", loc='left')
    if X[image].shape[-1] == 1:
        ax1.imshow(np.squeeze(X[image]), cmap='bone', vmin=0., vmax=1.)
    else:
        ax1.imshow(np.squeeze(X[image]), vmin=0., vmax=1.)
    ax1.axis('off')

    # Display the prediction bar
    ax2 = fig.add_subplot(gs[1])
    ax2.barh(list(class_name.keys()), np.squeeze(predictions, axis=0), color=plt.get_cmap('tab10').colors)
    ax2.set_title(f"Predicted class: {class_str} (Confidence: {max(np.squeeze(predictions, axis=0)):.2f})", loc='left')
    ax2.grid(alpha=0.3)
    ax2.set_xlim(0.0, 1.0)

    plt.show()

    # Display activations if required
    if display_activations:
        # Visualise the activations from the first convolutional layer
        fig, axes = plt.subplots(1, 8, figsize=(16, 14))
        for i in range(8):
            ax = axes[i]
            ax.imshow(first_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('First convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

        # Visualise the activations from the first pooling layer
        fig, axes = plt.subplots(2, 8, figsize=(16, 5))
        for i in range(16):
            ax = axes[i // 8, i % 8]
            ax.imshow(second_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('Second convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (1376, 8)

# %%
# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.8612
# Precision score over the test set: 0.8938
# Recall score over the test set: 0.8612
# F1 score over the test set: 0.867

# %% [markdown]
# # Basic Model on Blanaced Dataset plus Augmentation and Batch Normalization

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('increased_balanced_dataset_noBrightness_noContrast_noZoom.npz')
X = data['images']
y = data['labels']

# %%
class_name = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet",
}

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# %%
# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (15277, 96, 96, 3)
# Training Label Shape: (15277, 8)
# Validation Data Shape: (1698, 96, 96, 3)
# Validation Label Shape: (1698, 8)

# %%
# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Categorical label: [1. 0. 0. 0. 0. 0. 0. 0.]
# "Default" label: 0
# Classification:  Basophil

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

# Define a sequential model for image augmentation with various transformations
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(0.2),
    tfkl.RandomZoom(0.2),
#    tfkl.RandomBrightness(0.5, value_range=(0,1)),
#    tfkl.RandomContrast(0.75),
], name='Augmentation')

x = augmentation(inputs)

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.BatchNormalization(name='bn1')(x)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.BatchNormalization(name='bn2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='03-AdditionOfBachNorm')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "03-AdditionOfBachNorm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv1 (Conv2D)                      │ (None, 96, 96, 32)           │           896 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ bn1 (BatchNormalization)            │ (None, 96, 96, 32)           │           128 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act1 (Activation)                   │ (None, 96, 96, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp1 (MaxPooling2D)                  │ (None, 48, 48, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2 (Conv2D)                      │ (None, 48, 48, 64)           │        18,496 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ bn2 (BatchNormalization)            │ (None, 48, 48, 64)           │           256 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act2 (Activation)                   │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp2 (MaxPooling2D)                  │ (None, 24, 24, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ flatten (Flatten)                   │ (None, 36864)                │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 8)                    │       294,920 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ softmax (Activation)                │ (None, 8)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 314,696 (1.20 MB)
#  Trainable params: 314,504 (1.20 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.5055 - loss: 4.4485 - val_accuracy: 0.3604 - val_loss: 3.1236
# Epoch 2/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7747 - loss: 0.7454 - val_accuracy: 0.5271 - val_loss: 2.0284
# Epoch 3/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8100 - loss: 0.5881 - val_accuracy: 0.6402 - val_loss: 1.6714
# Epoch 4/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8406 - loss: 0.4707 - val_accuracy: 0.6307 - val_loss: 1.9113
# Epoch 5/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8374 - loss: 0.4972 - val_accuracy: 0.1708 - val_loss: 19.1828
# Epoch 6/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8151 - loss: 0.6848 - val_accuracy: 0.6449 - val_loss: 3.2852
# Epoch 7/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8566 - loss: 0.4226 - val_accuracy: 0.7114 - val_loss: 1.3130
# Epoch 8/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8826 - loss: 0.3205 - val_accuracy: 0.7073 - val_loss: 2.0649
# Epoch 9/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8839 - loss: 0.3139 - val_accuracy: 0.3899 - val_loss: 11.5162
# Epoch 10/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8866 - loss: 0.2977 - val_accuracy: 0.4817 - val_loss: 7.1237
# Epoch 11/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8821 - loss: 0.3138 - val_accuracy: 0.7892 - val_loss: 0.8542
# Epoch 12/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8795 - loss: 0.3520 - val_accuracy: 0.7055 - val_loss: 1.4398
# Epoch 13/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8817 - loss: 0.3134 - val_accuracy: 0.5289 - val_loss: 4.5143
# Epoch 14/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8907 - loss: 0.2982 - val_accuracy: 0.8422 - val_loss: 0.6104
# Epoch 15/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9036 - loss: 0.2424 - val_accuracy: 0.7933 - val_loss: 0.8899
# Epoch 16/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9083 - loss: 0.2321 - val_accuracy: 0.6549 - val_loss: 2.8691
# Epoch 17/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9056 - loss: 0.2328 - val_accuracy: 0.8392 - val_loss: 0.6326
# Epoch 18/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9035 - loss: 0.2422 - val_accuracy: 0.6190 - val_loss: 3.0842
# Epoch 19/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9049 - loss: 0.2474 - val_accuracy: 0.6943 - val_loss: 2.0875
# Epoch 20/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9095 - loss: 0.2339 - val_accuracy: 0.5819 - val_loss: 4.2470
# Epoch 21/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9161 - loss: 0.2124 - val_accuracy: 0.8280 - val_loss: 0.6977
# Epoch 22/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9154 - loss: 0.2092 - val_accuracy: 0.3216 - val_loss: 24.6350
# Epoch 23/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9162 - loss: 0.2172 - val_accuracy: 0.7927 - val_loss: 1.1122
# Epoch 24/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9141 - loss: 0.2191 - val_accuracy: 0.6667 - val_loss: 3.1574
# Epoch 25/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9132 - loss: 0.2280 - val_accuracy: 0.6631 - val_loss: 3.0559
# Epoch 26/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9163 - loss: 0.2122 - val_accuracy: 0.4806 - val_loss: 22.9269
# Epoch 27/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9152 - loss: 0.2162 - val_accuracy: 0.5913 - val_loss: 5.8254
# Epoch 28/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9158 - loss: 0.2130 - val_accuracy: 0.6932 - val_loss: 2.6541
# Epoch 29/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9144 - loss: 0.2138 - val_accuracy: 0.8563 - val_loss: 0.6705
# Epoch 30/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9151 - loss: 0.2198 - val_accuracy: 0.6920 - val_loss: 2.8036
# Epoch 31/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9174 - loss: 0.2055 - val_accuracy: 0.7945 - val_loss: 0.8331
# Epoch 32/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9158 - loss: 0.2105 - val_accuracy: 0.6814 - val_loss: 3.3709
# Epoch 33/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9121 - loss: 0.2205 - val_accuracy: 0.8510 - val_loss: 0.6150
# Epoch 34/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9158 - loss: 0.2087 - val_accuracy: 0.6101 - val_loss: 4.5040
# Epoch 35/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9205 - loss: 0.2028 - val_accuracy: 0.6360 - val_loss: 3.0290
# Epoch 36/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9204 - loss: 0.1995 - val_accuracy: 0.8039 - val_loss: 1.0709
# Epoch 37/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9216 - loss: 0.1962 - val_accuracy: 0.5530 - val_loss: 5.3524
# Epoch 38/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9193 - loss: 0.2014 - val_accuracy: 0.2591 - val_loss: 19.4912
# Epoch 39/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9178 - loss: 0.2070 - val_accuracy: 0.7809 - val_loss: 1.1616
# Epoch 40/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9165 - loss: 0.2058 - val_accuracy: 0.6720 - val_loss: 2.4157
# Epoch 41/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9150 - loss: 0.2115 - val_accuracy: 0.8057 - val_loss: 0.7914
# Epoch 42/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9211 - loss: 0.1935 - val_accuracy: 0.8534 - val_loss: 0.5683
# Epoch 43/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9220 - loss: 0.1932 - val_accuracy: 0.8640 - val_loss: 0.4798
# Epoch 44/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9229 - loss: 0.1917 - val_accuracy: 0.8728 - val_loss: 0.4023
# Epoch 45/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9226 - loss: 0.1868 - val_accuracy: 0.8663 - val_loss: 0.4710
# Epoch 46/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9227 - loss: 0.1866 - val_accuracy: 0.8793 - val_loss: 0.3835
# Epoch 47/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9240 - loss: 0.1856 - val_accuracy: 0.8799 - val_loss: 0.4166
# Epoch 48/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9223 - loss: 0.1858 - val_accuracy: 0.8740 - val_loss: 0.4326
# Epoch 49/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9227 - loss: 0.1851 - val_accuracy: 0.8693 - val_loss: 0.4668
# Epoch 50/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9233 - loss: 0.1851 - val_accuracy: 0.8651 - val_loss: 0.5255
# Epoch 51/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9244 - loss: 0.1850 - val_accuracy: 0.8445 - val_loss: 0.7082
# Epoch 52/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9240 - loss: 0.1853 - val_accuracy: 0.8681 - val_loss: 0.4906
# Epoch 53/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9239 - loss: 0.1848 - val_accuracy: 0.7479 - val_loss: 1.9820
# Epoch 54/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9232 - loss: 0.1850 - val_accuracy: 0.8722 - val_loss: 0.4327
# Epoch 55/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9177 - loss: 0.2058 - val_accuracy: 0.6125 - val_loss: 3.4609
# Epoch 56/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9038 - loss: 0.2507 - val_accuracy: 0.8392 - val_loss: 0.6547
# Epoch 57/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9185 - loss: 0.2078 - val_accuracy: 0.8510 - val_loss: 0.4980
# Epoch 58/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9214 - loss: 0.1943 - val_accuracy: 0.8563 - val_loss: 0.5404
# Epoch 59/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9233 - loss: 0.1868 - val_accuracy: 0.8693 - val_loss: 0.4753
# Epoch 60/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9233 - loss: 0.1865 - val_accuracy: 0.8804 - val_loss: 0.3984
# Epoch 61/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9243 - loss: 0.1842 - val_accuracy: 0.8640 - val_loss: 0.5088
# Epoch 62/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9241 - loss: 0.1838 - val_accuracy: 0.7809 - val_loss: 1.2352
# Epoch 63/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9237 - loss: 0.1845 - val_accuracy: 0.8675 - val_loss: 0.4554
# Epoch 64/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9238 - loss: 0.1843 - val_accuracy: 0.8734 - val_loss: 0.4294
# Epoch 65/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9228 - loss: 0.1846 - val_accuracy: 0.7998 - val_loss: 0.9591
# Epoch 66/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9232 - loss: 0.1847 - val_accuracy: 0.8722 - val_loss: 0.4705
# Epoch 67/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9234 - loss: 0.1838 - val_accuracy: 0.8351 - val_loss: 0.6507
# Epoch 68/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9235 - loss: 0.1833 - val_accuracy: 0.8221 - val_loss: 0.7628
# Epoch 69/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9225 - loss: 0.1841 - val_accuracy: 0.8846 - val_loss: 0.3955
# Epoch 70/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9230 - loss: 0.1836 - val_accuracy: 0.8663 - val_loss: 0.4550
# Epoch 71/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9236 - loss: 0.1839 - val_accuracy: 0.8810 - val_loss: 0.4137
# Epoch 72/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9229 - loss: 0.1843 - val_accuracy: 0.8687 - val_loss: 0.4555
# Epoch 73/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9184 - loss: 0.2060 - val_accuracy: 0.2656 - val_loss: 19.5816
# Epoch 74/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9143 - loss: 0.2138 - val_accuracy: 0.8693 - val_loss: 0.4195
# Epoch 75/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9222 - loss: 0.1920 - val_accuracy: 0.8787 - val_loss: 0.3881
# Epoch 76/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9219 - loss: 0.1883 - val_accuracy: 0.8669 - val_loss: 0.4328
# Epoch 77/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9230 - loss: 0.1838 - val_accuracy: 0.8746 - val_loss: 0.4175
# Epoch 78/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9230 - loss: 0.1836 - val_accuracy: 0.8734 - val_loss: 0.3981
# Epoch 79/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9235 - loss: 0.1834 - val_accuracy: 0.8746 - val_loss: 0.3959
# Epoch 80/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9225 - loss: 0.1837 - val_accuracy: 0.8834 - val_loss: 0.3684
# Epoch 81/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9234 - loss: 0.1835 - val_accuracy: 0.8840 - val_loss: 0.3918
# Epoch 82/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9242 - loss: 0.1836 - val_accuracy: 0.8716 - val_loss: 0.4339
# Epoch 83/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9226 - loss: 0.1836 - val_accuracy: 0.8822 - val_loss: 0.3832
# Epoch 84/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9231 - loss: 0.1838 - val_accuracy: 0.8769 - val_loss: 0.4060
# Epoch 85/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9221 - loss: 0.1835 - val_accuracy: 0.8840 - val_loss: 0.3685
# Epoch 86/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9225 - loss: 0.1829 - val_accuracy: 0.8828 - val_loss: 0.4070
# Epoch 87/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9230 - loss: 0.1834 - val_accuracy: 0.8846 - val_loss: 0.3998
# Epoch 88/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9235 - loss: 0.1830 - val_accuracy: 0.8751 - val_loss: 0.4640
# Epoch 89/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9229 - loss: 0.1919 - val_accuracy: 0.1402 - val_loss: 53.1996
# Final validation accuracy: 88.46%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_88.46.keras')

# %%
def extract_activations(model, X, num_images):

    # Identify the first convolutional layer
    first_conv_index = None
    for i, layer in enumerate(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            first_conv_index = i
            break

    if first_conv_index is None:
        raise ValueError("The model does not contain a 2D convolution")

    # Extract activations from the first convolutional layer
    first_conv = tfk.Sequential(model.layers[:first_conv_index + 1])
    first_activations = first_conv(X[:num_images])

    # Identify the first pooling layer after the first convolution
    pooling_index = None
    for i, layer in enumerate(model.layers[first_conv_index + 1:], start=first_conv_index + 1):
        if isinstance(layer, (tfk.layers.MaxPooling2D, tfk.layers.AveragePooling2D)):
            pooling_index = i
            break

    if pooling_index is None:
        raise ValueError("The model does not contain a 2D pooling operation after the first convolution")

    # Extract activations from the first convolution and the first pooling layer
    second_conv = tfk.Sequential(model.layers[:pooling_index + 1])
    second_activations = second_conv(X[:num_images])

    return first_activations, second_activations

def find_last_conv_layer(model):

    # Identify the last convolutional layer in the model
    for layer in reversed(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            return layer.name
    raise ValueError("No Conv2D layer found in the model.")

def visualize(model, X, y, unique_labels, num_images=50, display_activations=True):

    # Extract activations from the model
    first_activations, second_activations = extract_activations(model, X, num_images)

    # Select a random image for prediction and visualisation
    image = np.random.randint(0, num_images)
    predictions = model.predict(np.expand_dims(X[image], axis=0), verbose=0)
    class_int = np.argmax(predictions[0])
    class_str = unique_labels[class_int]

    # Create figure layout for displaying the image and predictions
    fig = plt.figure(constrained_layout=True, figsize=(16, 4))
    gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[1.5, 1.5], wspace=0)

    # Display the selected image with the true class
    ax1 = fig.add_subplot(gs[0])
    ax1.set_title(f"True class: {unique_labels[np.argmax(y[image])]}", loc='left')
    if X[image].shape[-1] == 1:
        ax1.imshow(np.squeeze(X[image]), cmap='bone', vmin=0., vmax=1.)
    else:
        ax1.imshow(np.squeeze(X[image]), vmin=0., vmax=1.)
    ax1.axis('off')

    # Display the prediction bar
    ax2 = fig.add_subplot(gs[1])
    ax2.barh(list(class_name.keys()), np.squeeze(predictions, axis=0), color=plt.get_cmap('tab10').colors)
    ax2.set_title(f"Predicted class: {class_str} (Confidence: {max(np.squeeze(predictions, axis=0)):.2f})", loc='left')
    ax2.grid(alpha=0.3)
    ax2.set_xlim(0.0, 1.0)

    plt.show()

    # Display activations if required
    if display_activations:
        # Visualise the activations from the first convolutional layer
        fig, axes = plt.subplots(1, 8, figsize=(16, 14))
        for i in range(8):
            ax = axes[i]
            ax.imshow(first_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('First convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

        # Visualise the activations from the first pooling layer
        fig, axes = plt.subplots(2, 8, figsize=(16, 5))
        for i in range(16):
            ax = axes[i // 8, i % 8]
            ax.imshow(second_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('Second convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (1887, 8)

# %%
# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.8601
# Precision score over the test set: 0.89
# Recall score over the test set: 0.8601
# F1 score over the test set: 0.8662

# %% [markdown]
# <hr>

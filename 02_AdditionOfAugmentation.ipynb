# %% [markdown]
# # Basic Model plus Augmetation

# %% [markdown]
# ## 🌐 Connect Colab to Google Drive

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/[2024-2025] AN2DL/
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/[2024-2025] AN2DL

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# %%
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

np.random.seed(42)
tf.random.set_seed(42);

import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

import matplotlib.gridspec as gridspec

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('training_set.npz')
X = data['images']
y = data['labels']

# %%
class_name = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet",
}

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# %%
# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (11144, 96, 96, 3)
# Training Label Shape: (11144, 8)
# Validation Data Shape: (1239, 96, 96, 3)
# Validation Label Shape: (1239, 8)

# %%
# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Categorical label: [1. 0. 0. 0. 0. 0. 0. 0.]
# "Default" label: 0
# Classification:  Basophil

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

# Define a sequential model for image augmentation with various transformations
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(0.2),
    tfkl.RandomZoom(0.2),
#    tfkl.RandomBrightness(0.5, value_range=(0,1)),
#    tfkl.RandomContrast(0.75),
], name='Augmentation')

x = augmentation(inputs)

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='02-AdditionOfAugmentation')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv1 (Conv2D)                      │ (None, 96, 96, 32)           │           896 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act1 (Activation)                   │ (None, 96, 96, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp1 (MaxPooling2D)                  │ (None, 48, 48, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2 (Conv2D)                      │ (None, 48, 48, 64)           │        18,496 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act2 (Activation)                   │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp2 (MaxPooling2D)                  │ (None, 24, 24, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ flatten (Flatten)                   │ (None, 36864)                │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 8)                    │       294,920 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ softmax (Activation)                │ (None, 8)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 314,312 (1.20 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.4447 - loss: 1.5412 - val_accuracy: 0.7272 - val_loss: 0.8008
# Epoch 2/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.7411 - loss: 0.7298 - val_accuracy: 0.7885 - val_loss: 0.6089
# Epoch 3/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7994 - loss: 0.5736 - val_accuracy: 0.7990 - val_loss: 0.5698
# Epoch 4/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8160 - loss: 0.5074 - val_accuracy: 0.8111 - val_loss: 0.5235
# Epoch 5/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8301 - loss: 0.4659 - val_accuracy: 0.8208 - val_loss: 0.4976
# Epoch 6/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8411 - loss: 0.4380 - val_accuracy: 0.8184 - val_loss: 0.5018
# Epoch 7/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8458 - loss: 0.4208 - val_accuracy: 0.8152 - val_loss: 0.5028
# Epoch 8/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8529 - loss: 0.3966 - val_accuracy: 0.8345 - val_loss: 0.4675
# Epoch 9/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8606 - loss: 0.3735 - val_accuracy: 0.8345 - val_loss: 0.4737
# Epoch 10/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8663 - loss: 0.3557 - val_accuracy: 0.8313 - val_loss: 0.4789
# Epoch 11/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8675 - loss: 0.3453 - val_accuracy: 0.8337 - val_loss: 0.4809
# Epoch 12/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8754 - loss: 0.3345 - val_accuracy: 0.8394 - val_loss: 0.4617
# Epoch 13/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8779 - loss: 0.3260 - val_accuracy: 0.8305 - val_loss: 0.4833
# Epoch 14/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8835 - loss: 0.3106 - val_accuracy: 0.8305 - val_loss: 0.5063
# Epoch 15/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8813 - loss: 0.3068 - val_accuracy: 0.8450 - val_loss: 0.4582
# Epoch 16/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8858 - loss: 0.2963 - val_accuracy: 0.8386 - val_loss: 0.4716
# Epoch 17/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8838 - loss: 0.2936 - val_accuracy: 0.8354 - val_loss: 0.4639
# Epoch 18/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8890 - loss: 0.2899 - val_accuracy: 0.8410 - val_loss: 0.4619
# Epoch 19/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8863 - loss: 0.2932 - val_accuracy: 0.8345 - val_loss: 0.5012
# Epoch 20/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8873 - loss: 0.2947 - val_accuracy: 0.8345 - val_loss: 0.4709
# Epoch 21/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8932 - loss: 0.2713 - val_accuracy: 0.8402 - val_loss: 0.5039
# Epoch 22/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8916 - loss: 0.2732 - val_accuracy: 0.8370 - val_loss: 0.4989
# Epoch 23/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8910 - loss: 0.2730 - val_accuracy: 0.8362 - val_loss: 0.5185
# Epoch 24/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8960 - loss: 0.2655 - val_accuracy: 0.8289 - val_loss: 0.5189
# Epoch 25/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8950 - loss: 0.2630 - val_accuracy: 0.8249 - val_loss: 0.5399
# Epoch 26/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8967 - loss: 0.2621 - val_accuracy: 0.8208 - val_loss: 0.5887
# Epoch 27/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8938 - loss: 0.2639 - val_accuracy: 0.8345 - val_loss: 0.5309
# Epoch 28/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8935 - loss: 0.2644 - val_accuracy: 0.8305 - val_loss: 0.5466
# Epoch 29/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8962 - loss: 0.2609 - val_accuracy: 0.8329 - val_loss: 0.5593
# Epoch 30/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8893 - loss: 0.2705 - val_accuracy: 0.8273 - val_loss: 0.5707
# Epoch 31/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8934 - loss: 0.2621 - val_accuracy: 0.8337 - val_loss: 0.5864
# Epoch 32/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8965 - loss: 0.2601 - val_accuracy: 0.8216 - val_loss: 0.6734
# Epoch 33/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8923 - loss: 0.2656 - val_accuracy: 0.8273 - val_loss: 0.6081
# Epoch 34/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8927 - loss: 0.2583 - val_accuracy: 0.8313 - val_loss: 0.5715
# Epoch 35/1000
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8916 - loss: 0.2637 - val_accuracy: 0.8345 - val_loss: 0.5627
# Final validation accuracy: 84.5%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_84.5.keras')

# %%
def extract_activations(model, X, num_images):

    # Identify the first convolutional layer
    first_conv_index = None
    for i, layer in enumerate(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            first_conv_index = i
            break

    if first_conv_index is None:
        raise ValueError("The model does not contain a 2D convolution")

    # Extract activations from the first convolutional layer
    first_conv = tfk.Sequential(model.layers[:first_conv_index + 1])
    first_activations = first_conv(X[:num_images])

    # Identify the first pooling layer after the first convolution
    pooling_index = None
    for i, layer in enumerate(model.layers[first_conv_index + 1:], start=first_conv_index + 1):
        if isinstance(layer, (tfk.layers.MaxPooling2D, tfk.layers.AveragePooling2D)):
            pooling_index = i
            break

    if pooling_index is None:
        raise ValueError("The model does not contain a 2D pooling operation after the first convolution")

    # Extract activations from the first convolution and the first pooling layer
    second_conv = tfk.Sequential(model.layers[:pooling_index + 1])
    second_activations = second_conv(X[:num_images])

    return first_activations, second_activations

def find_last_conv_layer(model):

    # Identify the last convolutional layer in the model
    for layer in reversed(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            return layer.name
    raise ValueError("No Conv2D layer found in the model.")

def visualize(model, X, y, unique_labels, num_images=50, display_activations=True):

    # Extract activations from the model
    first_activations, second_activations = extract_activations(model, X, num_images)

    # Select a random image for prediction and visualisation
    image = np.random.randint(0, num_images)
    predictions = model.predict(np.expand_dims(X[image], axis=0), verbose=0)
    class_int = np.argmax(predictions[0])
    class_str = unique_labels[class_int]

    # Create figure layout for displaying the image and predictions
    fig = plt.figure(constrained_layout=True, figsize=(16, 4))
    gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[1.5, 1.5], wspace=0)

    # Display the selected image with the true class
    ax1 = fig.add_subplot(gs[0])
    ax1.set_title(f"True class: {unique_labels[np.argmax(y[image])]}", loc='left')
    if X[image].shape[-1] == 1:
        ax1.imshow(np.squeeze(X[image]), cmap='bone', vmin=0., vmax=1.)
    else:
        ax1.imshow(np.squeeze(X[image]), vmin=0., vmax=1.)
    ax1.axis('off')

    # Display the prediction bar
    ax2 = fig.add_subplot(gs[1])
    ax2.barh(list(class_name.keys()), np.squeeze(predictions, axis=0), color=plt.get_cmap('tab10').colors)
    ax2.set_title(f"Predicted class: {class_str} (Confidence: {max(np.squeeze(predictions, axis=0)):.2f})", loc='left')
    ax2.grid(alpha=0.3)
    ax2.set_xlim(0.0, 1.0)

    plt.show()

    # Display activations if required
    if display_activations:
        # Visualise the activations from the first convolutional layer
        fig, axes = plt.subplots(1, 8, figsize=(16, 14))
        for i in range(8):
            ax = axes[i]
            ax.imshow(first_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('First convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

        # Visualise the activations from the first pooling layer
        fig, axes = plt.subplots(2, 8, figsize=(16, 5))
        for i in range(16):
            ax = axes[i // 8, i % 8]
            ax.imshow(second_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('Second convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (1376, 8)

# %%
# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.8241
# Precision score over the test set: 0.8723
# Recall score over the test set: 0.8241
# F1 score over the test set: 0.8363

# %% [markdown]
# # Basic Model on Balanced Dataset plus Augmetation (up sampling)

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('increased_balanced_dataset_noBrightness_noContrast_noZoom.npz')
X = data['images']
y = data['labels']

# %%
class_name = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet",
}

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# %%
# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (15277, 96, 96, 3)
# Training Label Shape: (15277, 8)
# Validation Data Shape: (1698, 96, 96, 3)
# Validation Label Shape: (1698, 8)

# %%
# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Categorical label: [1. 0. 0. 0. 0. 0. 0. 0.]
# "Default" label: 0
# Classification:  Basophil

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

# Define a sequential model for image augmentation with various transformations
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(0.2),
    tfkl.RandomZoom(0.2),
#    tfkl.RandomBrightness(0.5, value_range=(0,1)),
#    tfkl.RandomContrast(0.75),
], name='Augmentation')

x = augmentation(inputs)

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='02-AdditionOfAugmentation')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "02-AdditionOfAugmentation"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv1 (Conv2D)                      │ (None, 96, 96, 32)           │           896 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act1 (Activation)                   │ (None, 96, 96, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp1 (MaxPooling2D)                  │ (None, 48, 48, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2 (Conv2D)                      │ (None, 48, 48, 64)           │        18,496 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ act2 (Activation)                   │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mp2 (MaxPooling2D)                  │ (None, 24, 24, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ flatten (Flatten)                   │ (None, 36864)                │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 8)                    │       294,920 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ softmax (Activation)                │ (None, 8)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 314,312 (1.20 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.3871 - loss: 1.6480 - val_accuracy: 0.7067 - val_loss: 0.8685
# Epoch 2/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6908 - loss: 0.8677 - val_accuracy: 0.7450 - val_loss: 0.7014
# Epoch 3/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7653 - loss: 0.6592 - val_accuracy: 0.7774 - val_loss: 0.6191
# Epoch 4/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7907 - loss: 0.5839 - val_accuracy: 0.7868 - val_loss: 0.6037
# Epoch 5/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8130 - loss: 0.5237 - val_accuracy: 0.7903 - val_loss: 0.6049
# Epoch 6/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8277 - loss: 0.4780 - val_accuracy: 0.8045 - val_loss: 0.5652
# Epoch 7/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8451 - loss: 0.4387 - val_accuracy: 0.8127 - val_loss: 0.5388
# Epoch 8/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8525 - loss: 0.4110 - val_accuracy: 0.8115 - val_loss: 0.5401
# Epoch 9/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8584 - loss: 0.3891 - val_accuracy: 0.8269 - val_loss: 0.5125
# Epoch 10/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8637 - loss: 0.3719 - val_accuracy: 0.8257 - val_loss: 0.5032
# Epoch 11/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8676 - loss: 0.3600 - val_accuracy: 0.8351 - val_loss: 0.4716
# Epoch 12/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8744 - loss: 0.3461 - val_accuracy: 0.8433 - val_loss: 0.4401
# Epoch 13/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8778 - loss: 0.3405 - val_accuracy: 0.8357 - val_loss: 0.4561
# Epoch 14/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8825 - loss: 0.3215 - val_accuracy: 0.8428 - val_loss: 0.4317
# Epoch 15/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8885 - loss: 0.3000 - val_accuracy: 0.8316 - val_loss: 0.4729
# Epoch 16/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8942 - loss: 0.2874 - val_accuracy: 0.8375 - val_loss: 0.4494
# Epoch 17/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9011 - loss: 0.2703 - val_accuracy: 0.8469 - val_loss: 0.4331
# Epoch 18/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9031 - loss: 0.2642 - val_accuracy: 0.8416 - val_loss: 0.4493
# Epoch 19/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9062 - loss: 0.2569 - val_accuracy: 0.8369 - val_loss: 0.4612
# Epoch 20/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9077 - loss: 0.2520 - val_accuracy: 0.8392 - val_loss: 0.4702
# Epoch 21/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9057 - loss: 0.2467 - val_accuracy: 0.8481 - val_loss: 0.4713
# Epoch 22/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9090 - loss: 0.2407 - val_accuracy: 0.8280 - val_loss: 0.5226
# Epoch 23/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9093 - loss: 0.2426 - val_accuracy: 0.8333 - val_loss: 0.5118
# Epoch 24/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9121 - loss: 0.2358 - val_accuracy: 0.8451 - val_loss: 0.4745
# Epoch 25/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9113 - loss: 0.2342 - val_accuracy: 0.8292 - val_loss: 0.5182
# Epoch 26/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9106 - loss: 0.2336 - val_accuracy: 0.8469 - val_loss: 0.4604
# Epoch 27/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9103 - loss: 0.2312 - val_accuracy: 0.8351 - val_loss: 0.5837
# Epoch 28/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9158 - loss: 0.2225 - val_accuracy: 0.8422 - val_loss: 0.5306
# Epoch 29/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9160 - loss: 0.2187 - val_accuracy: 0.8280 - val_loss: 0.5759
# Epoch 30/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9191 - loss: 0.2110 - val_accuracy: 0.8127 - val_loss: 0.6723
# Epoch 31/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9166 - loss: 0.2216 - val_accuracy: 0.8233 - val_loss: 0.5849
# Epoch 32/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9169 - loss: 0.2146 - val_accuracy: 0.8304 - val_loss: 0.5868
# Epoch 33/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9175 - loss: 0.2126 - val_accuracy: 0.8168 - val_loss: 0.8022
# Epoch 34/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9160 - loss: 0.2176 - val_accuracy: 0.8298 - val_loss: 0.6030
# Epoch 35/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9191 - loss: 0.2119 - val_accuracy: 0.8345 - val_loss: 0.5762
# Epoch 36/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9186 - loss: 0.2066 - val_accuracy: 0.8345 - val_loss: 0.6390
# Epoch 37/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9178 - loss: 0.2113 - val_accuracy: 0.8327 - val_loss: 0.6372
# Epoch 38/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9224 - loss: 0.2018 - val_accuracy: 0.8322 - val_loss: 0.7070
# Epoch 39/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9218 - loss: 0.2011 - val_accuracy: 0.8304 - val_loss: 0.6414
# Epoch 40/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9161 - loss: 0.2149 - val_accuracy: 0.8392 - val_loss: 0.6211
# Epoch 41/1000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9165 - loss: 0.2148 - val_accuracy: 0.8286 - val_loss: 0.6469
# Final validation accuracy: 84.81%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_84.81.keras')

# %%
def extract_activations(model, X, num_images):

    # Identify the first convolutional layer
    first_conv_index = None
    for i, layer in enumerate(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            first_conv_index = i
            break

    if first_conv_index is None:
        raise ValueError("The model does not contain a 2D convolution")

    # Extract activations from the first convolutional layer
    first_conv = tfk.Sequential(model.layers[:first_conv_index + 1])
    first_activations = first_conv(X[:num_images])

    # Identify the first pooling layer after the first convolution
    pooling_index = None
    for i, layer in enumerate(model.layers[first_conv_index + 1:], start=first_conv_index + 1):
        if isinstance(layer, (tfk.layers.MaxPooling2D, tfk.layers.AveragePooling2D)):
            pooling_index = i
            break

    if pooling_index is None:
        raise ValueError("The model does not contain a 2D pooling operation after the first convolution")

    # Extract activations from the first convolution and the first pooling layer
    second_conv = tfk.Sequential(model.layers[:pooling_index + 1])
    second_activations = second_conv(X[:num_images])

    return first_activations, second_activations

def find_last_conv_layer(model):

    # Identify the last convolutional layer in the model
    for layer in reversed(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            return layer.name
    raise ValueError("No Conv2D layer found in the model.")

def visualize(model, X, y, unique_labels, num_images=50, display_activations=True):

    # Extract activations from the model
    first_activations, second_activations = extract_activations(model, X, num_images)

    # Select a random image for prediction and visualisation
    image = np.random.randint(0, num_images)
    predictions = model.predict(np.expand_dims(X[image], axis=0), verbose=0)
    class_int = np.argmax(predictions[0])
    class_str = unique_labels[class_int]

    # Create figure layout for displaying the image and predictions
    fig = plt.figure(constrained_layout=True, figsize=(16, 4))
    gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[1.5, 1.5], wspace=0)

    # Display the selected image with the true class
    ax1 = fig.add_subplot(gs[0])
    ax1.set_title(f"True class: {unique_labels[np.argmax(y[image])]}", loc='left')
    if X[image].shape[-1] == 1:
        ax1.imshow(np.squeeze(X[image]), cmap='bone', vmin=0., vmax=1.)
    else:
        ax1.imshow(np.squeeze(X[image]), vmin=0., vmax=1.)
    ax1.axis('off')

    # Display the prediction bar
    ax2 = fig.add_subplot(gs[1])
    ax2.barh(list(class_name.keys()), np.squeeze(predictions, axis=0), color=plt.get_cmap('tab10').colors)
    ax2.set_title(f"Predicted class: {class_str} (Confidence: {max(np.squeeze(predictions, axis=0)):.2f})", loc='left')
    ax2.grid(alpha=0.3)
    ax2.set_xlim(0.0, 1.0)

    plt.show()

    # Display activations if required
    if display_activations:
        # Visualise the activations from the first convolutional layer
        fig, axes = plt.subplots(1, 8, figsize=(16, 14))
        for i in range(8):
            ax = axes[i]
            ax.imshow(first_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('First convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

        # Visualise the activations from the first pooling layer
        fig, axes = plt.subplots(2, 8, figsize=(16, 5))
        for i in range(16):
            ax = axes[i // 8, i % 8]
            ax.imshow(second_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('Second convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (1887, 8)

# %%
# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.8225
# Precision score over the test set: 0.8498
# Recall score over the test set: 0.8225
# F1 score over the test set: 0.8269

# %% [markdown]
# # Basic Model on Balanced Dataset plus Augmetation (down sampling)

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load the training data here
data = np.load('reduced_balanced_dataset.npz')
X = data['images']
y = data['lables']

# %%
class_name = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet",
}

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size = 0.1,
    random_state=seed
)

# %% [markdown]
# <h3> Data Normalization and Encoding </h3>
# <hr>

# %%
# Normalize data to the range [0, 1]
X_train_val = (X_train_val / 255).astype('float32')
X_test = (X_test / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

# %%
# Split data into training and validation sets, maintaining class distribution
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", X_train.shape)
print("Training Label Shape:", y_train.shape)
print("Validation Data Shape:", X_val.shape)
print("Validation Label Shape:", y_val.shape)
# Out:
# Training Data Shape: (6908, 96, 96, 3)
# Training Label Shape: (6908, 8)
# Validation Data Shape: (768, 96, 96, 3)
# Validation Label Shape: (768, 8)

# %%
# Compare categorical label and "default" label representation
# Display the categorical label
print('Categorical label:', y_train[0])
# Display the equivalent numeric label
print('"Default" label:', np.argmax(y_train[0]))
print('Classification: ', class_name[np.argmax(y_train[0])])
# Out:
# Categorical label: [0. 0. 0. 0. 1. 0. 0. 0.]
# "Default" label: 4
# Classification:  Lymphocyte

# %% [markdown]
# <h3> Input and Output Shape </h3>
# <hr>

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (96, 96, 3)
# Output shape of the network 8

# %% [markdown]
# <h3> Other Parameters Definition </h3>
# <hr>

# %%
# Learning rate?: step size for updating the model's weights
learning_rate = 0.001

# Define the batch size for training
batch_size = 64

# Define the number of training epochs
epochs = 1000

# Create an empty dictionary to store metadata
metadata = {}

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
tf.random.set_seed(seed)

# Build the neural network layer by layer
inputs = tfkl.Input(shape=input_shape, name='Input')

# Define a sequential model for image augmentation with various transformations
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(0.2),
    tfkl.RandomZoom(0.2),
#    tfkl.RandomBrightness(0.5, value_range=(0,1)),
#    tfkl.RandomContrast(0.75),
], name='Augmentation')

x = augmentation(inputs)

x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
x = tfkl.Activation('relu', name='act1')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
x = tfkl.Activation('relu', name='act2')(x)
x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

x = tfkl.Flatten(name='flatten')(x)

x = tfkl.Dense(units=output_shape, name='dense')(x)
outputs = tfkl.Activation('softmax', name='softmax')(x)

# Connect input and output through the Model class
model = tfk.Model(inputs=inputs, outputs=outputs, name='02-AdditionOfAugmentation')

# Compile the model
loss = tfk.losses.CategoricalCrossentropy()
optimizer = tfk.optimizers.Adam(learning_rate)
metrics = ['accuracy']
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'BLOOD_CNN_TEST_'+str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model
# Out:
# Epoch 1/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.2830 - loss: 1.8727 - val_accuracy: 0.5977 - val_loss: 1.2251
# Epoch 2/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5768 - loss: 1.1665 - val_accuracy: 0.7018 - val_loss: 0.8736
# Epoch 3/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6804 - loss: 0.8786 - val_accuracy: 0.7279 - val_loss: 0.7630
# Epoch 4/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7171 - loss: 0.7568 - val_accuracy: 0.7643 - val_loss: 0.6879
# Epoch 5/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7401 - loss: 0.7019 - val_accuracy: 0.7552 - val_loss: 0.6829
# Epoch 6/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7548 - loss: 0.6653 - val_accuracy: 0.7643 - val_loss: 0.6448
# Epoch 7/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7646 - loss: 0.6329 - val_accuracy: 0.7669 - val_loss: 0.6193
# Epoch 8/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7721 - loss: 0.6018 - val_accuracy: 0.7487 - val_loss: 0.6558
# Epoch 9/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7849 - loss: 0.5741 - val_accuracy: 0.7578 - val_loss: 0.6630
# Epoch 10/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7933 - loss: 0.5480 - val_accuracy: 0.7565 - val_loss: 0.6671
# Epoch 11/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7983 - loss: 0.5342 - val_accuracy: 0.7565 - val_loss: 0.6895
# Epoch 12/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8034 - loss: 0.5185 - val_accuracy: 0.7513 - val_loss: 0.7264
# Epoch 13/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8042 - loss: 0.5083 - val_accuracy: 0.7383 - val_loss: 0.7820
# Epoch 14/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8053 - loss: 0.4971 - val_accuracy: 0.7331 - val_loss: 0.8048
# Epoch 15/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8059 - loss: 0.4947 - val_accuracy: 0.7292 - val_loss: 0.7543
# Epoch 16/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8197 - loss: 0.4854 - val_accuracy: 0.7331 - val_loss: 0.7571
# Epoch 17/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8201 - loss: 0.4754 - val_accuracy: 0.7292 - val_loss: 0.8274
# Epoch 18/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8178 - loss: 0.4778 - val_accuracy: 0.7708 - val_loss: 0.6610
# Epoch 19/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8184 - loss: 0.4679 - val_accuracy: 0.7474 - val_loss: 0.7410
# Epoch 20/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8178 - loss: 0.4666 - val_accuracy: 0.7552 - val_loss: 0.7151
# Epoch 21/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8193 - loss: 0.4643 - val_accuracy: 0.7474 - val_loss: 0.7366
# Epoch 22/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8216 - loss: 0.4595 - val_accuracy: 0.7591 - val_loss: 0.7225
# Epoch 23/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8190 - loss: 0.4555 - val_accuracy: 0.7487 - val_loss: 0.7242
# Epoch 24/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8168 - loss: 0.4583 - val_accuracy: 0.7266 - val_loss: 0.9178
# Epoch 25/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8264 - loss: 0.4439 - val_accuracy: 0.7773 - val_loss: 0.6792
# Epoch 26/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8188 - loss: 0.4465 - val_accuracy: 0.7656 - val_loss: 0.6804
# Epoch 27/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8215 - loss: 0.4457 - val_accuracy: 0.7591 - val_loss: 0.7063
# Epoch 28/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8206 - loss: 0.4545 - val_accuracy: 0.7773 - val_loss: 0.6775
# Epoch 29/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8202 - loss: 0.4384 - val_accuracy: 0.7747 - val_loss: 0.7103
# Epoch 30/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8257 - loss: 0.4316 - val_accuracy: 0.7786 - val_loss: 0.6734
# Epoch 31/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8271 - loss: 0.4226 - val_accuracy: 0.7773 - val_loss: 0.6872
# Epoch 32/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8266 - loss: 0.4217 - val_accuracy: 0.7826 - val_loss: 0.6920
# Epoch 33/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8265 - loss: 0.4202 - val_accuracy: 0.7773 - val_loss: 0.6954
# Epoch 34/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8266 - loss: 0.4157 - val_accuracy: 0.7695 - val_loss: 0.6973
# Epoch 35/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8271 - loss: 0.4153 - val_accuracy: 0.7695 - val_loss: 0.7078
# Epoch 36/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8273 - loss: 0.4146 - val_accuracy: 0.7708 - val_loss: 0.7196
# Epoch 37/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8261 - loss: 0.4141 - val_accuracy: 0.7682 - val_loss: 0.7297
# Epoch 38/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8281 - loss: 0.4132 - val_accuracy: 0.7773 - val_loss: 0.6958
# Epoch 39/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8299 - loss: 0.4131 - val_accuracy: 0.7812 - val_loss: 0.7069
# Epoch 40/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8284 - loss: 0.4134 - val_accuracy: 0.7591 - val_loss: 0.7561
# Epoch 41/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8281 - loss: 0.4124 - val_accuracy: 0.7734 - val_loss: 0.7199
# Epoch 42/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8274 - loss: 0.4120 - val_accuracy: 0.7852 - val_loss: 0.6946
# Epoch 43/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8282 - loss: 0.4115 - val_accuracy: 0.7773 - val_loss: 0.7050
# Epoch 44/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8266 - loss: 0.4114 - val_accuracy: 0.7721 - val_loss: 0.7591
# Epoch 45/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8271 - loss: 0.4109 - val_accuracy: 0.7799 - val_loss: 0.7243
# Epoch 46/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8302 - loss: 0.4105 - val_accuracy: 0.7682 - val_loss: 0.6935
# Epoch 47/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8263 - loss: 0.4108 - val_accuracy: 0.7643 - val_loss: 0.6982
# Epoch 48/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8272 - loss: 0.4105 - val_accuracy: 0.7695 - val_loss: 0.6739
# Epoch 49/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8261 - loss: 0.4100 - val_accuracy: 0.7708 - val_loss: 0.6699
# Epoch 50/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8269 - loss: 0.4096 - val_accuracy: 0.7695 - val_loss: 0.6728
# Epoch 51/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8273 - loss: 0.4095 - val_accuracy: 0.7734 - val_loss: 0.7456
# Epoch 52/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8283 - loss: 0.4099 - val_accuracy: 0.7669 - val_loss: 0.7125
# Epoch 53/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8212 - loss: 0.4289 - val_accuracy: 0.7786 - val_loss: 0.7623
# Epoch 54/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8275 - loss: 0.4156 - val_accuracy: 0.7487 - val_loss: 0.8752
# Epoch 55/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8198 - loss: 0.4421 - val_accuracy: 0.7318 - val_loss: 0.8067
# Epoch 56/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8162 - loss: 0.4454 - val_accuracy: 0.7786 - val_loss: 0.7551
# Epoch 57/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8279 - loss: 0.4124 - val_accuracy: 0.7630 - val_loss: 0.7387
# Epoch 58/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8257 - loss: 0.4106 - val_accuracy: 0.7708 - val_loss: 0.7587
# Epoch 59/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8266 - loss: 0.4103 - val_accuracy: 0.7865 - val_loss: 0.7697
# Epoch 60/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8301 - loss: 0.4099 - val_accuracy: 0.7826 - val_loss: 0.7739
# Epoch 61/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8309 - loss: 0.4101 - val_accuracy: 0.7747 - val_loss: 0.7418
# Epoch 62/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8252 - loss: 0.4095 - val_accuracy: 0.7852 - val_loss: 0.7440
# Epoch 63/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8284 - loss: 0.4099 - val_accuracy: 0.7786 - val_loss: 0.7858
# Epoch 64/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8281 - loss: 0.4266 - val_accuracy: 0.7474 - val_loss: 0.8156
# Epoch 65/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8013 - loss: 0.4864 - val_accuracy: 0.7747 - val_loss: 0.7678
# Epoch 66/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8254 - loss: 0.4138 - val_accuracy: 0.7708 - val_loss: 0.7410
# Epoch 67/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8250 - loss: 0.4104 - val_accuracy: 0.7708 - val_loss: 0.7506
# Epoch 68/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8251 - loss: 0.4098 - val_accuracy: 0.7747 - val_loss: 0.7593
# Epoch 69/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8259 - loss: 0.4095 - val_accuracy: 0.7734 - val_loss: 0.7639
# Epoch 70/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8266 - loss: 0.4093 - val_accuracy: 0.7721 - val_loss: 0.7679
# Epoch 71/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8257 - loss: 0.4092 - val_accuracy: 0.7669 - val_loss: 0.7730
# Epoch 72/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8257 - loss: 0.4092 - val_accuracy: 0.7695 - val_loss: 0.7707
# Epoch 73/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8270 - loss: 0.4091 - val_accuracy: 0.7708 - val_loss: 0.7613
# Epoch 74/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8278 - loss: 0.4089 - val_accuracy: 0.7721 - val_loss: 0.7589
# Epoch 75/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8276 - loss: 0.4088 - val_accuracy: 0.7721 - val_loss: 0.7577
# Epoch 76/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8256 - loss: 0.4087 - val_accuracy: 0.7721 - val_loss: 0.7451
# Epoch 77/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8254 - loss: 0.4086 - val_accuracy: 0.7760 - val_loss: 0.7488
# Epoch 78/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8270 - loss: 0.4086 - val_accuracy: 0.7747 - val_loss: 0.7522
# Epoch 79/1000
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8273 - loss: 0.4085 - val_accuracy: 0.7760 - val_loss: 0.7735
# Final validation accuracy: 78.65%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# <h3> Model Analysis </h3>
# <hr>

# %%
# Load the saved model
model = tfk.models.load_model('BLOOD_CNN_TEST_78.65.keras')

# %%
def extract_activations(model, X, num_images):

    # Identify the first convolutional layer
    first_conv_index = None
    for i, layer in enumerate(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            first_conv_index = i
            break

    if first_conv_index is None:
        raise ValueError("The model does not contain a 2D convolution")

    # Extract activations from the first convolutional layer
    first_conv = tfk.Sequential(model.layers[:first_conv_index + 1])
    first_activations = first_conv(X[:num_images])

    # Identify the first pooling layer after the first convolution
    pooling_index = None
    for i, layer in enumerate(model.layers[first_conv_index + 1:], start=first_conv_index + 1):
        if isinstance(layer, (tfk.layers.MaxPooling2D, tfk.layers.AveragePooling2D)):
            pooling_index = i
            break

    if pooling_index is None:
        raise ValueError("The model does not contain a 2D pooling operation after the first convolution")

    # Extract activations from the first convolution and the first pooling layer
    second_conv = tfk.Sequential(model.layers[:pooling_index + 1])
    second_activations = second_conv(X[:num_images])

    return first_activations, second_activations

def find_last_conv_layer(model):

    # Identify the last convolutional layer in the model
    for layer in reversed(model.layers):
        if isinstance(layer, tfk.layers.Conv2D):
            return layer.name
    raise ValueError("No Conv2D layer found in the model.")

def visualize(model, X, y, unique_labels, num_images=50, display_activations=True):

    # Extract activations from the model
    first_activations, second_activations = extract_activations(model, X, num_images)

    # Select a random image for prediction and visualisation
    image = np.random.randint(0, num_images)
    predictions = model.predict(np.expand_dims(X[image], axis=0), verbose=0)
    class_int = np.argmax(predictions[0])
    class_str = unique_labels[class_int]

    # Create figure layout for displaying the image and predictions
    fig = plt.figure(constrained_layout=True, figsize=(16, 4))
    gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[1.5, 1.5], wspace=0)

    # Display the selected image with the true class
    ax1 = fig.add_subplot(gs[0])
    ax1.set_title(f"True class: {unique_labels[np.argmax(y[image])]}", loc='left')
    if X[image].shape[-1] == 1:
        ax1.imshow(np.squeeze(X[image]), cmap='bone', vmin=0., vmax=1.)
    else:
        ax1.imshow(np.squeeze(X[image]), vmin=0., vmax=1.)
    ax1.axis('off')

    # Display the prediction bar
    ax2 = fig.add_subplot(gs[1])
    ax2.barh(list(class_name.keys()), np.squeeze(predictions, axis=0), color=plt.get_cmap('tab10').colors)
    ax2.set_title(f"Predicted class: {class_str} (Confidence: {max(np.squeeze(predictions, axis=0)):.2f})", loc='left')
    ax2.grid(alpha=0.3)
    ax2.set_xlim(0.0, 1.0)

    plt.show()

    # Display activations if required
    if display_activations:
        # Visualise the activations from the first convolutional layer
        fig, axes = plt.subplots(1, 8, figsize=(16, 14))
        for i in range(8):
            ax = axes[i]
            ax.imshow(first_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('First convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

        # Visualise the activations from the first pooling layer
        fig, axes = plt.subplots(2, 8, figsize=(16, 5))
        for i in range(16):
            ax = axes[i // 8, i % 8]
            ax.imshow(second_activations[image, :, :, i], cmap='bone', vmin=0., vmax=1.)
            ax.axis('off')
            if i == 0:
                ax.set_title('Second convolution activations', loc='left')
        plt.tight_layout()
        plt.show()

# Example usage
visualize(model, X_test, y_test, class_name, display_activations=True)

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (853, 8)

# %%
# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(class_name.values()), yticklabels=list(class_name.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.7796
# Precision score over the test set: 0.8514
# Recall score over the test set: 0.7796
# F1 score over the test set: 0.7963

# %% [markdown]
# <hr>
